# %% [markdown]
# # Covid-19 Deaths Predictor

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('./data/owid-covid-data.csv')

# %%
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
data = data.fillna(method='ffill')
# Out:
# C:\Users\sitia\AppData\Local\Temp\ipykernel_32132\917065080.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method='ffill')

# %%
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
relevant_cols = data[['location', 'date', 'total_cases', 'total_deaths', 'new_cases', 'new_deaths',
                      'population_density', 'gdp_per_capita', 'hospital_beds_per_thousand', 'median_age']]

# %%
relevant_cols.head()
# Out:
#       location        date  total_cases  total_deaths  new_cases  new_deaths  \
# 0  Afghanistan  2020-01-05          0.0           0.0        0.0         0.0
# 1  Afghanistan  2020-01-06          0.0           0.0        0.0         0.0
# 2  Afghanistan  2020-01-07          0.0           0.0        0.0         0.0
# 3  Afghanistan  2020-01-08          0.0           0.0        0.0         0.0
# 4  Afghanistan  2020-01-09          0.0           0.0        0.0         0.0
#
#    population_density  gdp_per_capita  hospital_beds_per_thousand  median_age
# 0               54.42         1803.99                         0.5        18.6
# 1               54.42         1803.99                         0.5        18.6
# 2               54.42         1803.99                         0.5        18.6
# 3               54.42         1803.99                         0.5        18.6
# 4               54.42         1803.99                         0.5        18.6
